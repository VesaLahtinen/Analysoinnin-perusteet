# %%
import pandas as pd
import numpy as np
import csv

df = pd.read_csv("C:/Users/OMISTAJA/Downloads/ObesityDataSet_raw_and_data_sinthetic.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.astype({'Age' : 'int'})
df.head(10)
# Out:
#    Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0   21  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1   21  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2   23    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3   27    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4   22    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
# 5   29    Male    1.62    53.0   Sometimes  yes   2.0  3.0   no    no   2.0
# 6   23  Female    1.50    55.0   Sometimes  yes   3.0  3.0   no    no   2.0
# 7   22    Male    1.64    53.0   Sometimes   no   2.0  3.0   no    no   2.0
# 8   24    Male    1.78    64.0  Frequently  yes   3.0  3.0   no    no   2.0
# 9   22    Male    1.72    68.0          no  yes   2.0  3.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# ...

# %%
df.shape[0]
df.info()
df.shape
df.shape[1]
df.columns
df.index
df.values

column_data_types = df.dtypes
print(column_data_types)

column_data_type = df['Age'].dtype
print(column_data_type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   int64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df.sort_values("Age")
# Out:
#       Age  Gender    Height     Weight        CALC FAVC      FCVC  NCP  SCC  \
# 415    14    Male  1.710000  72.000000          no  yes  3.000000  3.0   no
# 116    15  Female  1.650000  86.000000          no  yes  3.000000  3.0   no
# 959    16  Female  1.613921  66.738769          no  yes  2.206399  1.0  yes
# 876    16  Female  1.608914  65.000000          no  yes  1.321028  1.0  yes
# 953    16  Female  1.616533  65.062945          no  yes  2.388168  1.0  yes
# ...   ...     ...       ...        ...         ...  ...       ...  ...  ...
# 1088   55    Male  1.657221  80.993213          no  yes  2.000000  3.0   no
# 1158   55    Male  1.673394  80.400306          no  yes  2.000000  3.0   no
# 92     55    Male  1.780000  84.000000  Frequently   no  3.000000  4.0  yes
# 252    56    Male  1.790000  90.000000  Frequently   no  2.000000  3.0   no
# 133    61  Female  1.650000  66.000000  Frequently  yes  3.000000  3.0   no
#
# ...

# %%
df.sort_values("Weight", ascending=False).round(2)
# Out:
#       Age  Gender  Height  Weight       CALC FAVC  FCVC   NCP SCC SMOKE  CH2O  \
# 344    18    Male    1.87  173.00  Sometimes  yes  3.00  3.00  no    no  2.00
# 502    21  Female    1.84  165.06  Sometimes  yes  3.00  3.00  no    no  2.41
# 1898   19  Female    1.79  160.94  Sometimes  yes  3.00  3.00  no    no  2.07
# 1910   21  Female    1.80  160.64  Sometimes  yes  3.00  3.00  no    no  2.40
# 1838   20  Female    1.81  155.87  Sometimes  yes  3.00  3.00  no    no  2.42
# ...   ...     ...     ...     ...        ...  ...   ...   ...  ..   ...   ...
# 588    18  Female    1.57   39.85  Sometimes  yes  1.21  1.72  no    no  1.18
# 636    19  Female    1.56   39.70  Sometimes  yes  1.89  2.22  no    no  2.01
# 589    19  Female    1.53   39.37  Sometimes  yes  1.52  3.00  no    no  1.98
# 725    19  Female    1.54   39.10  Sometimes  yes  1.12  3.00  no    no  2.00
# 395    20  Female    1.54   39.00  Sometimes  yes  1.00  3.00  no    no  2.00
#
# ...

# %%
df.sort_values(["Weight", "Height"], ascending=[True, False]).round(2)
# Out:
#       Age  Gender  Height  Weight       CALC FAVC  FCVC   NCP SCC SMOKE  CH2O  \
# 395    20  Female    1.54   39.00  Sometimes  yes  1.00  3.00  no    no  2.00
# 725    19  Female    1.54   39.10  Sometimes  yes  1.12  3.00  no    no  2.00
# 589    19  Female    1.53   39.37  Sometimes  yes  1.52  3.00  no    no  1.98
# 636    19  Female    1.56   39.70  Sometimes  yes  1.89  2.22  no    no  2.01
# 588    18  Female    1.57   39.85  Sometimes  yes  1.21  1.72  no    no  1.18
# ...   ...     ...     ...     ...        ...  ...   ...   ...  ..   ...   ...
# 1838   20  Female    1.81  155.87  Sometimes  yes  3.00  3.00  no    no  2.42
# 1910   21  Female    1.80  160.64  Sometimes  yes  3.00  3.00  no    no  2.40
# 1898   19  Female    1.79  160.94  Sometimes  yes  3.00  3.00  no    no  2.07
# 502    21  Female    1.84  165.06  Sometimes  yes  3.00  3.00  no    no  2.41
# 344    18    Male    1.87  173.00  Sometimes  yes  3.00  3.00  no    no  2.00
#
# ...

# %%
subset_df = df[["Age", "Height", "Weight"]].round(2)
print(subset_df)
# Out:
#       Age  Height  Weight
# 0      21    1.62   64.00
# 1      21    1.52   56.00
# 2      23    1.80   77.00
# 3      27    1.80   87.00
# 4      22    1.78   89.80
# ...   ...     ...     ...
# 2106   20    1.71  131.41
# 2107   21    1.75  133.74
# 2108   22    1.75  133.69
# 2109   24    1.74  133.35
# 2110   23    1.74  133.47
#
# [2111 rows x 3 columns]

# %%
subset_df0 = df[df['Weight'] > 100]
print(subset_df0)
# Out:
#       Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  SCC  \
# 10     26    Male  1.850000  105.000000   Sometimes  yes   3.0  3.0   no
# 16     27    Male  1.930000  102.000000   Sometimes  yes   2.0  1.0   no
# 68     30    Male  1.760000  112.000000  Frequently  yes   1.0  3.0  yes
# 134    30    Male  1.770000  109.000000   Sometimes  yes   3.0  3.0   no
# 165    30    Male  1.920000  130.000000   Sometimes   no   2.0  3.0   no
# ...   ...     ...       ...         ...         ...  ...   ...  ...  ...
# 2106   20  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0   no
# 2107   21  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0   no
# 2108   22  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0   no
# 2109   24  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0   no
# 2110   23  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0   no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %%
subset_df1 = df['Weight'] > 100
subset_df2 = df['SMOKE'] == "yes"
subset_df3 = df[subset_df1 & subset_df2]
subset_df3.head()
# Out:
#      Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 68    30    Male    1.76   112.0  Frequently  yes   1.0  3.0  yes   yes   2.0
# 165   30    Male    1.92   130.0   Sometimes   no   2.0  3.0   no   yes   1.0
# 202   26  Female    1.56   102.0   Sometimes  yes   3.0  3.0   no   yes   1.0
# 294   18    Male    1.86   110.0   Sometimes  yes   2.0  1.0   no   yes   2.0
# 305   23    Male    1.75   120.0   Sometimes  yes   2.0  3.0   no   yes   2.0
#
#     family_history_with_overweight  FAF  TUE       CAEC  \
# 68                             yes  0.0  0.0         no
# 165                            yes  1.0  0.0  Sometimes
# 202                            yes  0.0  1.0  Sometimes
# 294                            yes  1.0  2.0  Sometimes
# 305                            yes  2.0  1.0  Sometimes
#
#                     MTRANS        NObeyesdad
# 68              Automobile   Obesity_Type_II
# 165  Public_Transportation   Obesity_Type_II
# ...

# %%
def categorize_weight(Weight):
    if Weight < 50:
        return 'Low'
    elif Weight < 80:
        return 'Medium'
    else:
        return 'High'
        

df['weight_group'] = df['Weight'].apply(categorize_weight)
df.head()
# Out:
#    Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0   21  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1   21  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2   23    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3   27    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4   22    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# 0                            yes  0.0  1.0  Sometimes  Public_Transportation
# 1                            yes  3.0  0.0  Sometimes  Public_Transportation
# 2                            yes  2.0  1.0  Sometimes  Public_Transportation
# 3                             no  2.0  0.0  Sometimes                Walking
# 4                             no  0.0  0.0  Sometimes  Public_Transportation
#
#             NObeyesdad weight_group
# ...
